# %%
import sys
sys.path.append(".")

# %%
# !pip install pdfplumber python-docx
# Out:
# Requirement already satisfied: pdfplumber in c:\users\saibh\anaconda3\lib\site-packages (0.11.9)
# Requirement already satisfied: python-docx in c:\users\saibh\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: pdfminer.six==20251230 in c:\users\saibh\anaconda3\lib\site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in c:\users\saibh\anaconda3\lib\site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\saibh\anaconda3\lib\site-packages (from pdfplumber) (5.5.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\saibh\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\saibh\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (43.0.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\saibh\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\saibh\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\saibh\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\saibh\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.21)

# %%
# !python model/train_model.py

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\saibh\resumeAnalyzer

# %%
# !python -u model/train_model.py
# Out:
# Training script started...
# Loading dataset from: C:\Users\saibh\resumeAnalyzer\dataset\resume_data.csv
# Dataset loaded successfully
# Total rows: 9544
# Preparing text...
# Vectorizing text...
# Training model...
# Model Accuracy: 1.0
# Model saved successfully!

# %%
from resume_parser.extract_text import extract_text_from_pdf
from model.predict_role import predict_role
from skill_extraction.skill_extractor import extract_skills
from ats_scoring.skill_gap_analysis import skill_gap
from ats_scoring.ats_score import calculate_score

# %%
resume_text = extract_text_from_pdf("uploades/resume.pdf")

print(resume_text[:500])
# Out:
# GEMBALI SAI BHARGAVI
# FullStack&CloudEnthusiast
# Email: saibhargavigembali2236@gmail.com Phone: +91-6302150046 Location: Visakhapatnam,AP
# LinkedIn: linkedin.com/in/saibhargavi-gembali-4b0550350/ GitHub: github.com/Saibhargavi2236
# Career Objective
# Motivated Full Stack Developer with hands-on experience in MERN stack and AWS cloud services, building
# scalablewebapplicationsanddata-drivensolutions.
# Key Skills
# • Frontend: HTML,CSS,JavaScript,React
# • Backend&Databases: Node.js,MySQL,MongoDB
# • Languages:

# %%
role = predict_role(resume_text)

print("Predicted Job Role:", role)
# Out:
# Predicted Job Role: Mechanical Engineer

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df['job_position_name'].value_counts().head(20)
#
# NameError: name 'df' is not defined
